# %% [markdown]
# # Pre-processing procedures
#
# This notebook will set you up to run quotation detection of a source text in a target corpus, processing both as needed and storing them in a convenient location. You should run every cell in this notebook except those marked "OPTIONAL". Cells that say "ACTION" require you to do something within the cell before running it.
#
#
# NOTE, before you open this notebook, make sure you've run the following command on the command line to increase Jupyter notebook memory:
#
# `jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10`
#
# If you've already opened this notebook, close it, run the command above, and open the notebook from within the browser that pops up.

# %% [markdown]
# # Initial setup

# %%
import pandas as pd
import json
import os

# %%
# ACTION: Specify info on dataset here so all files and folders will be named consistently
authorSurname = "Foucault"
publicationYear = "1969"
textTitle = "Archaeology"
# NB use one or two unique keywords for text title

# %%
projectName = f"{authorSurname}_{publicationYear}_{textTitle}"

print(projectName)
# Out:
# Foucault_1969_Archaeology

# %%
# ACTION: Specify a directory for data to be stored

dataDir = "/Users/milan/Library/CloudStorage/GoogleDrive-mtt2126@columbia.edu/My Drive/iAnnotate/MIT/Quotable Content/Data"

# %%
# Create subfolders for source text and corpus

sourceDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Source"
corpusDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Corpus"

os.makedirs(f"{sourceDir}", exist_ok=True)
os.makedirs(f"{corpusDir}", exist_ok=True)

# %% [markdown]
# # Target corpus

# %%
# ACTION: specify the location of the JSONL file downloaded from JSTOR.
# On a Mac, you can do this by locating the file in Finder, right-clicking, holding the "opt" key
# and selecting "Copy ... as Pathname" then pasting it between the quotation marks below.

path_to_jsonLines_file = '/Users/milan/Downloads/foucault-archaeology.jsonl'

with open(path_to_jsonLines_file) as f: 
    rawCorpus = f.readlines()

# Parse the JSTORdata line by line (processing each line of jsonl individually)
data = [json.loads(line) for line in rawCorpus]

# NB running this cell can take 5+ mins with files >5GB

# %%
# Dump the parsed JSONL into a new JSON array called ""
name_of_parsed_file = f"{corpusDir}/{projectName}.json"

with open(name_of_parsed_file, 'w') as outfile: 
    json.dump(data, outfile)

# NB running this cell can take 5+ mins with files >5GB

# %%
df = pd.read_json(name_of_parsed_file)
df

# NB running this cell can take 5+ mins with files >5GB, and sometimes crashes the kernel but works when restarted
# Out:
#                                  creator datePublished        docSubType  \
# 0                         [JOHN MAYNARD]    1996-12-01       book-review
# 1                         [Julia Riches]    1996-01-01       book-review
# 2                        [Jérôme Thélot]    2014-01-01  research-article
# 3                                    NaN    2013-04-01             other
# 4                   [J. Stephen Lansing]    2003-08-01  research-article
# ...                                  ...           ...               ...
# 30210                   [Brendan Dooley]    1997-12-01       book-review
# 30211  [Louis Althusser, Richard Veasey]    1993-10-01  research-article
# 30212                                NaN    1962-03-01              misc
# 30213                [Anthony Guneratne]    2016-10-01  research-article
# 30214                  [Adele E. Clarke]    2003-11-01  research-article
#
#        docType                                           fullText  \
# 0      article  [REVIEWS / 597 KOPELSON, KEVIN. Love 's Litany...
# 1      article  [Review Essay REVIEW ESSAY: READING THE BODY b...
# 2      article  [Jerome Thélot Prosodie et histoire Qu'il s'ag...
# 3      article  [contributors linda martín alcoff is professo...
# 4      article  [J. STEPHEN LANSING University of Arizona and ...
# ...        ...                                                ...
# 30210  article  [Book Reviews Fantasy and Reality in History. ...
# 30211  article  [?t:?::??:!? 1 ?i?lillsa;;? ?o?j?-;? i .. r* ....
# 30212  article  [VIENNENT DE PARAITRE Emile Copfermann La géné...
# 30213  article  [The Greatest Shakespeare Film Never Made: Tex...
# 30214  article  [Situational Analyses: Grounded Theory Mapping...
#
#                                                       id  \
# 0                   http://www.jstor.org/stable/29533170
# 1                   http://www.jstor.org/stable/30003241
# 2                   http://www.jstor.org/stable/45073935
# 3      http://www.jstor.org/stable/10.5325/critphilra...
# 4                    http://www.jstor.org/stable/3805433
# ...                                                  ...
# 30210         http://www.jstor.org/stable/10.1086/245598
# 30211               http://www.jstor.org/stable/25007697
# 30212               http://www.jstor.org/stable/24255976
# 30213               http://www.jstor.org/stable/26355195
# 30214  http://www.jstor.org/stable/10.1525/si.2003.26...
#
#                                               identifier  \
# 0      [{'name': 'issn', 'value': '00393827'}, {'name...
# 1      [{'name': 'issn', 'value': '13513818'}, {'name...
# 2      [{'name': 'issn', 'value': '12684082'}, {'name...
# 3      [{'name': 'issn', 'value': '21658684'}, {'name...
# 4      [{'name': 'issn', 'value': '00940496'}, {'name...
# ...                                                  ...
# 30210  [{'name': 'issn', 'value': '00222801'}, {'name...
# 30211  [{'name': 'issn', 'value': '07345496'}, {'name...
# 30212  [{'name': 'issn', 'value': '00140759'}, {'name...
# 30213  [{'name': 'issn', 'value': '07482558'}, {'name...
# 30214  [{'name': 'issn', 'value': '01956086'}, {'name...
#
#                                 isPartOf issueNumber language  ...  \
# 0                   Studies in the Novel           4    [eng]  ...
# 1      Irish Journal of American Studies         NaN    [eng]  ...
# 2                     L'Année Baudelaire         NaN    [fre]  ...
# 3            Critical Philosophy of Race           1    [eng]  ...
# 4                   American Ethnologist           3    [eng]  ...
# ...                                  ...         ...      ...  ...
# 30210      The Journal of Modern History           4    [eng]  ...
# 30211                       Grand Street          47    [eng]  ...
# 30212                     Esprit (1940-)     304 (3)    [fre]  ...
# 30213               Shakespeare Bulletin           3    [eng]  ...
# 30214               Symbolic Interaction           4    [eng]  ...
#
#                                                    title  \
# 0                                         Review Article
# 1                                       Reading the Body
# 2                                   Prosodie et histoire
# 3                                            Back Matter
# 4      The Cognitive Machinery of Power: Reflections ...
# ...                                                  ...
# 30210                                       Book Reviews
# 30211                                  Zones of Darkness
# 30212                                        Back Matter
# 30213           The Greatest Shakespeare Film Never Made
# 30214  Situational Analyses: Grounded Theory Mapping ...
#
#                                                      url volumeNumber  \
# 0                   http://www.jstor.org/stable/29533170           28
# 1                   http://www.jstor.org/stable/30003241            5
# 2                   http://www.jstor.org/stable/45073935        18/19
# 3      http://www.jstor.org/stable/10.5325/critphilra...            1
# 4                    http://www.jstor.org/stable/3805433           30
# ...                                                  ...          ...
# 30210         http://www.jstor.org/stable/10.1086/245598           69
# 30211               http://www.jstor.org/stable/25007697          NaN
# 30212               http://www.jstor.org/stable/24255976          NaN
# 30213               http://www.jstor.org/stable/26355195           34
# 30214  http://www.jstor.org/stable/10.1525/si.2003.26...           26
#
#       wordCount                                           abstract  \
# 0          1566                                                NaN
# 1          6906                                                NaN
# 2          7350                                                NaN
# 3           877                                                NaN
# 4          8042  As Judith Butler has emphasized, for Michel Fo...
# ...         ...                                                ...
# 30210     60891                                                NaN
# 30211      8060                                                NaN
# 30212      3730                                                NaN
# 30213      8956                                                NaN
# 30214     11241  To better address differences and complexities...
#
#                                      subTitle  keyphrase collection  \
# 0                                         NaN        NaN        NaN
# 1                                         NaN        NaN        NaN
# 2                                         NaN        NaN        NaN
# 3                                         NaN        NaN        NaN
# 4                                         NaN        NaN        NaN
# ...                                       ...        ...        ...
# 30210                                     NaN        NaN        NaN
# 30211                                     NaN        NaN        NaN
# 30212                                     NaN        NaN        NaN
# 30213  Textualities, Authorship, and Archives        NaN        NaN
# 30214                                     NaN        NaN        NaN
#
#       hasPartTitle editor
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
# ...            ...    ...
# 30210          NaN    NaN
# 30211          NaN    NaN
# 30212          NaN    NaN
# 30213          NaN    NaN
# 30214          NaN    NaN
#
# [30215 rows x 30 columns]

# %%
# Drop the columns containing ngrams (irrelevant to our research) and overwrite JSON file

df.drop(['unigramCount', 'bigramCount', 'trigramCount'], inplace=True, axis=1)
df.to_json(f'{projectName}.json')

# %% [markdown]
# # Browsing the contents of the dataset

# %%
# Get general info on data

df.info
# Out:
# <bound method DataFrame.info of                                  creator datePublished        docSubType  \
# 0                         [JOHN MAYNARD]    1996-12-01       book-review
# 1                         [Julia Riches]    1996-01-01       book-review
# 2                        [Jérôme Thélot]    2014-01-01  research-article
# 3                                    NaN    2013-04-01             other
# 4                   [J. Stephen Lansing]    2003-08-01  research-article
# ...                                  ...           ...               ...
# 30210                   [Brendan Dooley]    1997-12-01       book-review
# 30211  [Louis Althusser, Richard Veasey]    1993-10-01  research-article
# 30212                                NaN    1962-03-01              misc
# 30213                [Anthony Guneratne]    2016-10-01  research-article
# 30214                  [Adele E. Clarke]    2003-11-01  research-article
#
#        docType                                           fullText  \
# 0      article  [REVIEWS / 597 KOPELSON, KEVIN. Love 's Litany...
# 1      article  [Review Essay REVIEW ESSAY: READING THE BODY b...
# 2      article  [Jerome Thélot Prosodie et histoire Qu'il s'ag...
# 3      article  [contributors linda martín alcoff is professo...
# 4      article  [J. STEPHEN LANSING University of Arizona and ...
# ...        ...                                                ...
# 30210  article  [Book Reviews Fantasy and Reality in History. ...
# 30211  article  [?t:?::??:!? 1 ?i?lillsa;;? ?o?j?-;? i .. r* ....
# 30212  article  [VIENNENT DE PARAITRE Emile Copfermann La géné...
# 30213  article  [The Greatest Shakespeare Film Never Made: Tex...
# 30214  article  [Situational Analyses: Grounded Theory Mapping...
#
#                                                       id  \
# 0                   http://www.jstor.org/stable/29533170
# 1                   http://www.jstor.org/stable/30003241
# 2                   http://www.jstor.org/stable/45073935
# 3      http://www.jstor.org/stable/10.5325/critphilra...
# 4                    http://www.jstor.org/stable/3805433
# ...                                                  ...
# 30210         http://www.jstor.org/stable/10.1086/245598
# 30211               http://www.jstor.org/stable/25007697
# 30212               http://www.jstor.org/stable/24255976
# 30213               http://www.jstor.org/stable/26355195
# 30214  http://www.jstor.org/stable/10.1525/si.2003.26...
#
#                                               identifier  \
# 0      [{'name': 'issn', 'value': '00393827'}, {'name...
# 1      [{'name': 'issn', 'value': '13513818'}, {'name...
# 2      [{'name': 'issn', 'value': '12684082'}, {'name...
# 3      [{'name': 'issn', 'value': '21658684'}, {'name...
# 4      [{'name': 'issn', 'value': '00940496'}, {'name...
# ...                                                  ...
# 30210  [{'name': 'issn', 'value': '00222801'}, {'name...
# 30211  [{'name': 'issn', 'value': '07345496'}, {'name...
# 30212  [{'name': 'issn', 'value': '00140759'}, {'name...
# 30213  [{'name': 'issn', 'value': '07482558'}, {'name...
# 30214  [{'name': 'issn', 'value': '01956086'}, {'name...
#
#                                 isPartOf issueNumber language  ...  \
# 0                   Studies in the Novel           4    [eng]  ...
# 1      Irish Journal of American Studies         NaN    [eng]  ...
# 2                     L'Année Baudelaire         NaN    [fre]  ...
# 3            Critical Philosophy of Race           1    [eng]  ...
# 4                   American Ethnologist           3    [eng]  ...
# ...                                  ...         ...      ...  ...
# 30210      The Journal of Modern History           4    [eng]  ...
# 30211                       Grand Street          47    [eng]  ...
# 30212                     Esprit (1940-)     304 (3)    [fre]  ...
# 30213               Shakespeare Bulletin           3    [eng]  ...
# 30214               Symbolic Interaction           4    [eng]  ...
#
#                                                    title  \
# 0                                         Review Article
# 1                                       Reading the Body
# 2                                   Prosodie et histoire
# 3                                            Back Matter
# 4      The Cognitive Machinery of Power: Reflections ...
# ...                                                  ...
# 30210                                       Book Reviews
# 30211                                  Zones of Darkness
# 30212                                        Back Matter
# 30213           The Greatest Shakespeare Film Never Made
# 30214  Situational Analyses: Grounded Theory Mapping ...
#
#                                                      url volumeNumber  \
# 0                   http://www.jstor.org/stable/29533170           28
# 1                   http://www.jstor.org/stable/30003241            5
# 2                   http://www.jstor.org/stable/45073935        18/19
# 3      http://www.jstor.org/stable/10.5325/critphilra...            1
# 4                    http://www.jstor.org/stable/3805433           30
# ...                                                  ...          ...
# 30210         http://www.jstor.org/stable/10.1086/245598           69
# 30211               http://www.jstor.org/stable/25007697          NaN
# 30212               http://www.jstor.org/stable/24255976          NaN
# 30213               http://www.jstor.org/stable/26355195           34
# 30214  http://www.jstor.org/stable/10.1525/si.2003.26...           26
#
#       wordCount                                           abstract  \
# 0          1566                                                NaN
# 1          6906                                                NaN
# 2          7350                                                NaN
# 3           877                                                NaN
# 4          8042  As Judith Butler has emphasized, for Michel Fo...
# ...         ...                                                ...
# 30210     60891                                                NaN
# 30211      8060                                                NaN
# 30212      3730                                                NaN
# 30213      8956                                                NaN
# 30214     11241  To better address differences and complexities...
#
#                                      subTitle  keyphrase collection  \
# 0                                         NaN        NaN        NaN
# 1                                         NaN        NaN        NaN
# 2                                         NaN        NaN        NaN
# 3                                         NaN        NaN        NaN
# 4                                         NaN        NaN        NaN
# ...                                       ...        ...        ...
# 30210                                     NaN        NaN        NaN
# 30211                                     NaN        NaN        NaN
# 30212                                     NaN        NaN        NaN
# 30213  Textualities, Authorship, and Archives        NaN        NaN
# 30214                                     NaN        NaN        NaN
#
#       hasPartTitle editor
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
# ...            ...    ...
# 30210          NaN    NaN
# 30211          NaN    NaN
# 30212          NaN    NaN
# 30213          NaN    NaN
# 30214          NaN    NaN
#
# [30215 rows x 30 columns]>

# %%
# Identify items lacking full text

df.loc[pd.isnull(df['fullText'])]
# Out:
# Empty DataFrame
# Columns: [creator, datePublished, docSubType, docType, fullText, id, identifier, isPartOf, issueNumber, language, outputFormat, pageCount, pageEnd, pageStart, pagination, provider, publicationYear, publisher, sourceCategory, tdmCategory, title, url, volumeNumber, wordCount, abstract, subTitle, keyphrase, collection, hasPartTitle, editor]
# Index: []
#
# [0 rows x 30 columns]

# %%
# Identify items that include full text

df.loc[pd.notnull(df['fullText'])]
# Out:
#                                  creator datePublished        docSubType  \
# 0                  [Christophe Ippolito]    2008-01-01  research-article
# 1                                    NaN    1990-11-01              misc
# 2                          [Ian Finseth]    1999-04-01  research-article
# 3                     [Vern L. Bullough]    1989-07-01  research-article
# 4                       [George Huppert]    1974-10-01  research-article
# ...                                  ...           ...               ...
# 10415                      [MONIKA KAUP]    2013-12-01  research-article
# 10416                [Alexander Spencer]    2014-08-01  research-article
# 10417     [פלג דור-חיים, Peleg Dor-haim]    2015-01-01  research-article
# 10418  [Michelle Bigenho, Henry Stobart]    2018-10-01  research-article
# 10419                   [Jason E. Glenn]    2001-11-01  research-article
#
#        docType                                           fullText  \
# 0      article  [THE TWENTIETH CENTURY, 1900-1945 By Christoph...
# 1      article  [S OO -~~~ SeL~~~~s ai g; g; g, ; a a~ W ' S A...
# 2      article  [ESSAYS How Shall the Truth Be Told? Language ...
# 3      article  [THE FIELDING H. GARRISON LECTURE* M THE PHYSI...
# 4      article  [DIVINATlO ET ERUDJTlO: THOUGHTS ON FOUCAULT G...
# ...        ...                                                ...
# 10415  article  [MONIKA KAUP The Neobaroque in W. G. Sebald's ...
# 10416  article  [International Studies Perspectives (2014) 15,...
# 10417  article  [הקבוצה הדינמית כמרחב להתמודדות עם ניכור וזרות...
# 10418  article  [SPECIAL COLLECTION WORLD HERITAGE AND THE ONT...
# 10419  article  [A SECOND FAILED RECONSTRUCTION? THE COUNTER R...
#
#                                          id  \
# 0      http://www.jstor.org/stable/25834090
# 1       http://www.jstor.org/stable/2073165
# 2      http://www.jstor.org/stable/27746772
# 3      http://www.jstor.org/stable/44451381
# 4       http://www.jstor.org/stable/2504776
# ...                                     ...
# 10415  http://www.jstor.org/stable/43297932
# 10416  http://www.jstor.org/stable/44218756
# 10417  http://www.jstor.org/stable/26240971
# 10418  http://www.jstor.org/stable/26646268
# 10419  http://www.jstor.org/stable/23019782
#
#                                               identifier  \
# 0      [{'name': 'issn', 'value': '00844152'}, {'name...
# 1      [{'name': 'issn', 'value': '00943061'}, {'name...
# 2      [{'name': 'issn', 'value': '00029823'}, {'name...
# 3      [{'name': 'issn', 'value': '00075140'}, {'name...
# 4      [{'name': 'issn', 'value': '00182656'}, {'name...
# ...                                                  ...
# 10415  [{'name': 'issn', 'value': '00107484'}, {'name...
# 10416  [{'name': 'issn', 'value': '15283577'}, {'name...
# 10417  [{'name': 'issn', 'value': '23102063'}, {'name...
# 10418  [{'name': 'issn', 'value': '00035491'}, {'name...
# 10419  [{'name': 'issn', 'value': '02588501'}, {'name...
#
#                                                 isPartOf language  \
# 0             The Year's Work in Modern Language Studies    [eng]
# 1                                 Contemporary Sociology    [eng]
# 2                   American Literary Realism, 1870-1910    [eng]
# 3                    Bulletin of the History of Medicine    [eng]
# 4                                     History and Theory    [eng]
# ...                                                  ...      ...
# 10415                            Contemporary Literature    [eng]
# 10416                 International Studies Perspectives    [eng]
# 10417  Mikbatz: The Israel Journal of Group Psychothe...    [heb]
# 10418                          Anthropological Quarterly    [eng]
# 10419                  Journal of West Indian Literature    [eng]
#
#                      outputFormat  ...  \
# 0      [unigram, bigram, trigram]  ...
# 1      [unigram, bigram, trigram]  ...
# 2      [unigram, bigram, trigram]  ...
# 3      [unigram, bigram, trigram]  ...
# 4      [unigram, bigram, trigram]  ...
# ...                           ...  ...
# 10415  [unigram, bigram, trigram]  ...
# 10416  [unigram, bigram, trigram]  ...
# 10417  [unigram, bigram, trigram]  ...
# 10418  [unigram, bigram, trigram]  ...
# 10419  [unigram, bigram, trigram]  ...
#
#                                                    title  \
# 0                       THE TWENTIETH CENTURY, 1900–1945
# 1                                           Front Matter
# 2      How Shall the Truth Be Told? Language and Race...
# 3      THE PHYSICIAN AND RESEARCH INTO HUMAN SEXUAL B...
# 4            Divinatio et Eruditio: Thoughts on Foucault
# ...                                                  ...
# 10415  The Neobaroque in W. G. Sebald's "The Rings of...
# 10416  Romantic Stories of the Pirate in IARRRH: The ...
# 10417  The Intimate Group as a Space of Coping with A...
# 10418  Grasping Cacophony in Bolivian Heritage Otherwise
# 10419  A SECOND FAILED RECONSTRUCTION? THE COUNTER RE...
#
#                                         url volumeNumber wordCount  \
# 0      http://www.jstor.org/stable/25834090           70      7727
# 1       http://www.jstor.org/stable/2073165           19      2776
# 2      http://www.jstor.org/stable/27746772           31     10192
# 3      http://www.jstor.org/stable/44451381           63     10778
# 4       http://www.jstor.org/stable/2504776           13      8105
# ...                                     ...          ...       ...
# 10415  http://www.jstor.org/stable/43297932           54     13599
# 10416  http://www.jstor.org/stable/44218756           15      9289
# 10417  http://www.jstor.org/stable/26240971           19      5248
# 10418  http://www.jstor.org/stable/26646268           91     15207
# 10419  http://www.jstor.org/stable/23019782           10     18475
#
#       issueNumber                                           abstract subTitle  \
# 0             NaN                                                NaN      NaN
# 1               6                                                NaN      NaN
# 2               3                                                NaN      NaN
# 3               2                                                NaN      NaN
# 4               3                                                NaN      NaN
# ...           ...                                                ...      ...
# 10415           4                                                NaN      NaN
# 10416           3  The article examines the attempt by some acade...      NaN
# 10417           2  לאורך ההיסטוריה האנושית מילאה "הקבוצה האינטימי...      NaN
# 10418           4  A "fever" of heritage registration (patrimonia...      NaN
# 10419         1/2                                                NaN      NaN
#
#       keyphrase collection hasPartTitle
# 0           NaN        NaN          NaN
# 1           NaN        NaN          NaN
# 2           NaN        NaN          NaN
# 3           NaN        NaN          NaN
# 4           NaN        NaN          NaN
# ...         ...        ...          ...
# 10415       NaN        NaN          NaN
# 10416       NaN        NaN          NaN
# 10417       NaN        NaN          NaN
# 10418       NaN        NaN          NaN
# 10419       NaN        NaN          NaN
#
# [10420 rows x 29 columns]

# %%
# Examine an item in detail

# ACTION: Choose an index at random from 0 to the highest number listed above

article_index = 41

# Print summary of metadata and text
print(df.loc[article_index])
# Out:
# creator                                             [Maggie McBride]
# datePublished                                             1989-02-01
# docSubType                                          research-article
# docType                                                      article
# fullText           [A Foucauldian Analysis of Mathematical Discou...
# id                              http://www.jstor.org/stable/40247944
# identifier         [{'name': 'issn', 'value': '02280671'}, {'name...
# isPartOf                             For the Learning of Mathematics
# issueNumber                                                        1
# language                                                       [eng]
# outputFormat                              [unigram, bigram, trigram]
# pageCount                                                        7.0
# pageEnd                                                           46
# pageStart                                                         40
# pagination                                                 pp. 40-46
# provider                                                       jstor
# publicationYear                                                 1989
# publisher                                 FLM Publishing Association
# sourceCategory     [Education, Mathematics, Science and Mathemati...
# tdmCategory                        [Philosophy - Applied philosophy]
# title               A Foucauldian Analysis of Mathematical Discourse
# url                             http://www.jstor.org/stable/40247944
# volumeNumber                                                       9
# wordCount                                                       6455
# abstract                                                         NaN
# subTitle                                                         NaN
# keyphrase                                                        NaN
# collection                                                       NaN
# hasPartTitle                                                     NaN
# editor                                                           NaN
# Name: 41, dtype: object

# %%
# Print full text for item examined above
print(df['fullText'].loc[article_index])
# Out:
# ['A Foucauldian Analysis of Mathematical Discourse MAGGIE MCBR1DE The important thing, I believe, is that truth isn\'t outside power, or lacking in power: contrary to a myth . . . truth isn\'t the reward of free spirits, . . . nor the privilege of those who have succeeded in liberating themselves . . . Truth is a thing of this world . . . Each society has its regime of truth: that is, the types of discourse which it accepts and makes function as true . . .[1] As I read these words of Michel Foucault, I cannot help but become more aware of the politics of my own teaching of mathematics. If 1 take my study of Foucault seriously, I must think about changing my teaching practices. In the past, I saw improvement or change in my teaching as a personal endeavor; now, however, it has become more than that- it is a political struggle in which 1 have begun to question how the teaching of mathematics has been constructed to empower certain individuals who engage in certain practices. Foucault has helped me identify the construction of mathematics as well as to diffuse some of my anger concerning the traditional teaching of mathe- matics. His work provides me with means to articulate the contradictions I have been feeling in my teaching and to identify other ways of viewing and teaching mathematics. As a graduate teaching assistant in a university mathe- matics department, I taught the "weeder" calculus courses as I finished my master\'s degree. The Mathematics Department functioned as a service department to the Engineering Department. The first-quarter freshman cal- culus course had enrollments of several hundred young men, and the rigor and disconnectedness with which 1 taught the classes and gave the exams guaranteed that the filtering process started the first quarter. This unfeeling approach continued for these students through six or more quarters of calculus and differential equations. I never thought about this practice even though I did not particularly enjoy sensing the frustration of so many students, particularly many of the women. What I enjoyed was a deluded sense of separateness from those who struggled with their prejudices, irrational decisions, and generally messy lives. I played with fantasies of obtaining my master\'s degree and becoming a mathema- tician in an area with few women. But what Foucault has suggested to me is that in teaching mathematics courses, a way of knowing is modeled and supported that sets the contents of mathematics courses "out there somewhere" for the chosen few to grasp like a golden ring on a merry- go-round; these chosen few are more likely to be men than women. I wondered how such a system is perpetuated - a system that seems to be the result of the incorporation of a masculine structuring, masculine concerns, and mas- culine discourse in the sciences. In this paper, I will use the ideas of Foucault to analyze how gender is conceptualized in the teaching of mathe- matics. More specifically, I will bring out features implicit in the teaching of mathematics that continually support and perpetuate a dominant discourse of "truth" in the world of mathematics that reflects a male perspective on the world. My data will be various components of mathematics discourse as I have observed them in my own experiences as an instructor of mathematics. I will use as my method of analysis Michel Foucault\'s notions of power and knowledge as they function to create and support discursive formations. While some feminist schol- ars in the social sciences have used Foucault\'s writings to conduct feminist critiques, none have applied his ideas to the discipline of mathematics. [2] In talking about the term "masculine" here, I do not wish to make this an issue of males versus females in mathematics classes. "Masculine" refers to a cognitive style, not a biological category. Traits of this cognitive style are objectivity, separation, control of knower over nature, and a strictly intellectual way of knowing that de ...
