# %% [markdown]
# <font size=5>Run Text_Matcher Algorithm</font>

# %%
#Troubleshooting: !jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10 if you 
# get a message about the data rate limit
from matcher import Text, Matcher
import json
import pandas as pd
from IPython.display import clear_output

# %%
# ACTION: copy path to corpus data JSONL file here (filename should end "_fulltext.jsonl")

startData = "/Users/milan/Library/CloudStorage/GoogleDrive-mtt2126@columbia.edu/My Drive/iAnnotate/MIT/Quotable Content/Data/Woolf/1925_Dalloway/Corpus/Woolf_1925_Dalloway_fulltext.jsonl"

# %%
# Infer naming variables from path

textTitle = startData.rsplit("_", 3)[-2]
publicationYear = startData.rsplit("_", 3)[-3]
authorSurname = startData.rsplit("_", 3)[-4]
authorSurname = authorSurname.rsplit("/", 1)[-1]
dataDir = startData.rsplit("/", 4)[0]

print(f"Author surname: {authorSurname}\nPublication year: {publicationYear}\nText title: {textTitle}\nData directory:{dataDir}")
# Out:
# Author surname: Woolf
# Publication year: 1925
# Text title: Dalloway
# Data directory:/Users/milan/Library/CloudStorage/GoogleDrive-mtt2126@columbia.edu/My Drive/iAnnotate/MIT/Quotable Content/Data

# %%
# Load variables
projectName = f"{authorSurname}_{publicationYear}_{textTitle}"
sourceDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Source"
corpusDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Corpus"
resultsDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Results"

# %%
corpusFile = f"{corpusDir}/{projectName}_fulltext.jsonl"
with open(corpusFile) as f:
    rawProcessedData = f.readlines()
data = [json.loads(line) for line in rawProcessedData]

# Load the text you want to find quotations from. Replace text with the text file you want to use.

sourceText = f"{sourceDir}/{projectName}_plaintext.txt"
with open(sourceText) as f: 
    rawText = f.read()

tx = Text(rawText, projectName)

# %%
for i, article in enumerate(data): 
    clear_output()
    print('\r', 'Matching article %s of %s' % (i, len(data)), end='')
    if 'numMatches' not in article: 
        articleText = Text(article['fullText'], article['id'])
        article['numMatches'], article['Locations in A'], article['Locations in B'] = \
        Matcher(tx, articleText).match()
        article['fullText'] = ''
# Out:
#  Matching article 2494 of 2495

# %%
df = pd.DataFrame(data)
df = df.drop(['fullText'], axis=1)

df.to_json(path_or_buf=f"{resultsDir}/{projectName}_results.jsonl", orient='records', lines=True)

# %% [markdown]
# # Quality control

# %%
# Optional: reload results file (if resuming later)

resultsData = f"{resultsDir}/{projectName}_results.jsonl"
df = pd.read_json(resultsData, lines=True)

# %%
# Check that matcher ran on all lines in the dataset - result should be 0

df.loc[pd.isnull(df['Locations in A'])]
# Out:
# Empty DataFrame
# Columns: [creator, datePublished, docSubType, docType, id, identifier, isPartOf, issueNumber, language, outputFormat, pageCount, pageEnd, pageStart, pagination, provider, publicationYear, publisher, sourceCategory, tdmCategory, title, url, volumeNumber, wordCount, numMatches, Locations in A, Locations in B, doi, keyphrase, abstract, placeOfPublication, subTitle]
# Index: []
#
# [0 rows x 31 columns]

# %%
# Check how many items include at least 1 match

df.loc[df["numMatches"] >=1]
# Out:
#                         creator datePublished        docSubType  docType  \
# 2                 [Ian Finseth]    1999-04-01  research-article  article
# 15            [Gunther Teubner]    1989-01-01  research-article  article
# 38     [Karen Elizabeth Bishop]    2011-10-01       book-review  article
# 56             [Heike Schaefer]    2015-01-01  research-article  article
# 63             [Henk-Jan Kooij]    2015-11-01  research-article  article
# ...                         ...           ...               ...      ...
# 10332            [Colin Pedley]    1990-04-01  research-article  article
# 10336              [Tim Murphy]    2003-01-01  research-article  article
# 10378  [Samuel Hideo Yamashita]    1992-12-01       book-review  article
# 10406                      None    1976-11-01              misc  article
# 10410         [OMNIA EL SHAKRY]    2015-06-01  research-article  article
#
#                                          id  \
# 2      http://www.jstor.org/stable/27746772
# 15      http://www.jstor.org/stable/3053760
# 38     http://www.jstor.org/stable/41238302
# 56     http://www.jstor.org/stable/44071899
# 63     http://www.jstor.org/stable/26098720
# ...                                     ...
# 10332  http://www.jstor.org/stable/24042557
# 10336  http://www.jstor.org/stable/23550011
# 10378   http://www.jstor.org/stable/2719183
# 10406   http://www.jstor.org/stable/3129679
# 10410  http://www.jstor.org/stable/26577264
#
#                                               identifier  \
# 2      [{'name': 'issn', 'value': '00029823'}, {'name...
# 15     [{'name': 'issn', 'value': '00239216'}, {'name...
# 38     [{'name': 'issn', 'value': '02613050'}, {'name...
# 56     [{'name': 'issn', 'value': '03402827'}, {'name...
# 63     [{'name': 'issn', 'value': '14730952'}, {'name...
# ...                                                  ...
# 10332  [{'name': 'issn', 'value': '00438006'}, {'name...
# 10336  [{'name': 'issn', 'value': '09433058'}, {'name...
# 10378  [{'name': 'issn', 'value': '00730548'}, {'name...
# 10406  [{'name': 'issn', 'value': '0065972X'}, {'name...
# 10410  [{'name': 'issn', 'value': '00028762'}, {'name...
#
#                                                 isPartOf language  \
# 2                   American Literary Realism, 1870-1910    [eng]
# 15                                  Law & Society Review    [eng]
# 38                   Bulletin of Latin American Research    [eng]
# 56                     Amerikastudien / American Studies    [eng]
# 63                                       Planning Theory    [eng]
# ...                                                  ...      ...
# 10332                              The Wordsworth Circle    [eng]
# 10336           Method & Theory in the Study of Religion    [eng]
# 10378                 Harvard Journal of Asiatic Studies    [eng]
# 10406  Proceedings and Addresses of the American Phil...    [eng]
# 10410                     The American Historical Review    [eng]
#
#                      outputFormat  pageCount  ... wordCount numMatches  \
# 2      [unigram, bigram, trigram]       20.0  ...     10192          1
# 15     [unigram, bigram, trigram]       31.0  ...     14124          1
# 38     [unigram, bigram, trigram]        3.0  ...       865          1
# 56     [unigram, bigram, trigram]       18.0  ...      9602          1
# 63     [unigram, bigram, trigram]       21.0  ...     10661          1
# ...                           ...        ...  ...       ...        ...
# 10332  [unigram, bigram, trigram]        7.0  ...      6019          1
# 10336  [unigram, bigram, trigram]       20.0  ...      8693          1
# 10378  [unigram, bigram, trigram]       14.0  ...      4781          1
# 10406  [unigram, bigram, trigram]       49.0  ...     12039          1
# 10410  [unigram, bigram, trigram]       15.0  ...      9788          1
#
#            Locations in A    Locations in B  issueNumber  \
# 2      [[113193, 113396]]  [[52257, 52460]]            3
# 15     [[121523, 121709]]  [[23103, 23288]]            5
# 38     [[333653, 333937]]      [[206, 489]]            4
# 56       [[52485, 52730]]  [[10716, 10960]]            1
# 63     [[106799, 106888]]  [[11698, 11788]]            4
# ...                   ...               ...          ...
# 10332    [[52485, 52730]]  [[30417, 30663]]            2
# 10336    [[52485, 52730]]  [[46238, 46484]]            1
# 10378    [[89391, 89609]]    [[8971, 9195]]            2
# 10406       [[887, 1029]]  [[52708, 52849]]            2
# 10410  [[329500, 329632]]  [[24000, 24129]]            3
#
#                                                 abstract  \
# 2                                                   None
# 15                                                  None
# 38                                                  None
# 56     While the study of networks has proliferated i...
# 63     AbstractA central question within planning the...
# ...                                                  ...
# 10332                                               None
# 10336  This work is a synopsis of an argument for a s...
# 10378                                               None
# 10406                                               None
# 10410                                               None
#
#                                                 subTitle keyphrase collection  \
# 2                                                   None      None       None
# 15                                                  None      None       None
# 38                                                  None      None       None
# 56                                                  None      None       None
# 63              The innovation campus in the Netherlands      None       None
# ...                                                  ...       ...        ...
# 10332                                               None      None       None
# 10336                                               None      None       None
# 10378                                               None      None       None
# 10406                                               None      None       None
# 10410  The Vexed Archives of Decolonization in the Mi...      None       None
#
#       hasPartTitle
# 2             None
# 15            None
# 38            None
# 56            None
# 63            None
# ...            ...
# 10332         None
# 10336         None
# 10378         None
# 10406         None
# 10410         None
#
# [644 rows x 31 columns]

# %%
# Check some random items without matches to check for false negatives - easiest to refer to PDF


df.loc[df["numMatches"] == 0]
# Out:
#                                        creator datePublished  \
# 0                              [Ellen Tremper]    1994-07-01
# 1     [Beth Rigel Daugherty, Arnold Weinstein]    2007-01-01
# 2                          [Christine MacLeod]    1997-01-01
# 4                             [Frank Baldanza]    1958-07-01
# 5         [Jeannette H. Foster, David Daiches]    1940-07-01
# ...                                        ...           ...
# 2490                   [Mia Carter, ﻣﻴﺎ ﻛﺎﺭﺗﺭ]    2007-01-01
# 2491         [Shyam M. Asnani, Mulk Raj Anand]    1983-03-01
# 2492                 [Susan Stanford Friedman]    2013-04-01
# 2493                       [Judith Yaross Lee]    2009-01-01
# 2494                                       NaN    1987-10-01
#
#             docSubType   docType                                    id  \
# 0     research-article   article   http://www.jstor.org/stable/3831453
# 1                  NaN  document  http://www.jstor.org/stable/24907105
# 2          book-review   article   http://www.jstor.org/stable/3509206
# 4     research-article   article  http://www.jstor.org/stable/41395513
# 5                  NaN  document   http://www.jstor.org/stable/4302768
# ...                ...       ...                                   ...
# 2490               NaN  document  http://www.jstor.org/stable/30197973
# 2491               NaN  document  http://www.jstor.org/stable/23331532
# 2492               NaN  document  http://www.jstor.org/stable/43653363
# 2493               NaN  document  http://www.jstor.org/stable/42573565
# 2494              misc   article   http://www.jstor.org/stable/3831515
#
#                                              identifier  \
# 0     [{'name': 'issn', 'value': '0022281X'}, {'name...
# 1     [{'name': 'doi', 'value': '10.2307/24907105'},...
# 2     [{'name': 'issn', 'value': '03062473'}, {'name...
# 4     [{'name': 'doi', 'value': '10.2307/41395513'},...
# 5     [{'name': 'doi', 'value': '10.2307/4302768'}, ...
# ...                                                 ...
# 2490  [{'name': 'doi', 'value': '10.2307/30197973'},...
# 2491  [{'name': 'doi', 'value': '10.2307/23331532'},...
# 2492  [{'name': 'doi', 'value': '10.2307/43653363'},...
# 2493  [{'name': 'doi', 'value': '10.2307/42573565'},...
# 2494  [{'name': 'issn', 'value': '0022281X'}, {'name...
#
#                                                isPartOf issueNumber language  \
# 0                          Journal of Modern Literature           1    [eng]
# 1                                  Woolf Studies Annual         NaN    [eng]
# 2                       The Yearbook of English Studies         NaN    [eng]
# 4                                                   NaN           2    [eng]
# 5     The Library Quarterly: Information, Community,...           3    [eng]
# ...                                                 ...         ...      ...
# 2490               Alif: Journal of Comparative Poetics          27    [eng]
# 2491                                  Indian Literature           2    [eng]
# 2492                Tulsa Studies in Women's Literature           1    [eng]
# 2493                          Studies in American Humor          19    [eng]
# 2494                       Journal of Modern Literature         2/3    [eng]
#
#                        outputFormat  ...  volumeNumber wordCount numMatches  \
# 0        [unigram, bigram, trigram]  ...            19      5607          0
# 1     [unigrams, bigrams, trigrams]  ...            13      3021          0
# 2        [unigram, bigram, trigram]  ...            27      1210          0
# 4     [unigrams, bigrams, trigrams]  ...            12      7337          0
# 5     [unigrams, bigrams, trigrams]  ...            10      1652          0
# ...                             ...  ...           ...       ...        ...
# 2490  [unigrams, bigrams, trigrams]  ...           NaN     11192          0
# 2491  [unigrams, bigrams, trigrams]  ...            26      1706          0
# 2492  [unigrams, bigrams, trigrams]  ...            32     13023          0
# 2493  [unigrams, bigrams, trigrams]  ...           NaN     13888          0
# 2494     [unigram, bigram, trigram]  ...            14     63340          0
#
#      Locations in A Locations in B               doi  \
# 0                []             []               NaN
# 1                []             []  10.2307/24907105
# 2                []             []               NaN
# 4                []             []  10.2307/41395513
# 5                []             []   10.2307/4302768
# ...             ...            ...               ...
# 2490             []             []  10.2307/30197973
# 2491             []             []  10.2307/23331532
# 2492             []             []  10.2307/43653363
# 2493             []             []  10.2307/42573565
# 2494             []             []               NaN
#
#                                               keyphrase  \
# 0                                                   NaN
# 1     [weinstein, readers, moderns, woolf faulkner, ...
# 2                                                   NaN
# 4     [mccullers, miss mccullers, carson mccullers, ...
# 5     [daiches, bourgeois intellectual, civilization...
# ...                                                 ...
# 2490  [woolfs, passionate apprentice, virginia woolf...
# 2491  [indian, mulk raj, raj anand, dobree, british ...
# 2492  [cosmopolitanism, three guineas, persepolis, w...
# 2493  [keatons, dialect, vernacular, american, socia...
# 2494                                                NaN
#
#                                                abstract placeOfPublication  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 4                                                   NaN                NaN
# 5                                                   NaN                NaN
# ...                                                 ...                ...
# 2490  This article argues that Woolf's juvenilia, yo...                NaN
# 2491                                                NaN                NaN
# 2492  This comparative essay argues that Virginia Wo...                NaN
# 2493                                                NaN                NaN
# 2494                                                NaN                NaN
#
#      subTitle
# 0         NaN
# 1         NaN
# 2         NaN
# 4         NaN
# 5         NaN
# ...       ...
# 2490      NaN
# 2491      NaN
# 2492      NaN
# 2493      NaN
# 2494      NaN
#
# [2136 rows x 31 columns]
