# %% [markdown]
# <font size=5>Run Text_Matcher Algorithm</font>

# %%
#Troubleshooting: !jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10 if you 
# get a message about the data rate limit
from matcher import Text, Matcher
import json
import pandas as pd
from IPython.display import clear_output

# %%
# ACTION: specify top-level data directory and project info here
# Make sure they match the info you specified in preprocessing

dataDir = "/Users/milan/Library/CloudStorage/GoogleDrive-mtt2126@columbia.edu/My Drive/iAnnotate/MIT/Quotable Content/Data"
authorSurname = "Foucault"
publicationYear = "1969"
textTitle = "Archaeology"

# %%
# Load variables
projectName = f"{authorSurname}_{publicationYear}_{textTitle}"
sourceDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Source"
corpusDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Corpus"
resultsDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Results"

# %%
# Load the data.
corpusData = "/Users/milan/Downloads/foucault-archaeology.jsonl"
with open(corpusData) as f: 
    rawCorpus = f.readlines()

# Parse the data. 
data = [json.loads(line) for line in rawCorpus]

df = pd.DataFrame(data)
# Drop the irrelevant columns and rows with no full text.
df = df.drop(['url', 'outputFormat', 'volumeNumber', 'subTitle', 'provider', 'datePublished', \
              'pagination', 'pageEnd', 'pageStart'], axis=1)
df.dropna(subset=['fullText'], inplace=True)
df.to_json(path_or_buf=f'{projectName}_processed.jsonl', orient='records', lines=True)

processedData = f'{corpusDir}/{projectName}_processed.jsonl'
with open(processedData) as f:
    rawProcessedData = f.readlines()
data = [json.loads(line) for line in rawProcessedData]

# Load the text you want to find quotations from. Replace text with the text file you want to use.

sourceText = f"{sourceDir}/{projectName}_plaintext.txt"
with open(sourceText) as f: 
    rawText = f.read()

tx = Text(rawText, projectName)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 17
#      14 df.to_json(path_or_buf=f'{projectName}_processed.jsonl', orient='records', lines=True)
#      16 processedData = f'{corpusDir}/{projectName}_processed.jsonl'
# ---> 17 with open(processedData) as f:
#      18     rawProcessedData = f.readlines()
#      19 data = [json.loads(line) for line in rawProcessedData]
#
# File ~/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/milan/Library/CloudStorage/GoogleDrive-mtt2126@columbia.edu/My Drive/iAnnotate/MIT/Quotable Content/Data/Foucault/1969_Archaeology/Corpus/Foucault_1969_Archaeology_processed.jsonl'

# %%
processedData = "/Users/milan/Downloads/foucault-archaeology.jsonl"
with open(processedData) as f:
    rawProcessedData = f.readlines()
data = [json.loads(line) for line in rawProcessedData]

# Load the text you want to find quotations from. Replace text with the text file you want to use.

sourceText = f"{sourceDir}/{projectName}_plaintext.txt"
with open(sourceText) as f: 
    rawText = f.read()

tx = Text(rawText, projectName)

# %%
for i, article in enumerate(data): 
    clear_output()
    print('\r', 'Matching article %s of %s' % (i, len(data)), end='')
    if 'numMatches' not in article: 
        articleText = Text(article['fullText'], article['id'])
        article['numMatches'], article['Locations in A'], article['Locations in B'] = \
        Matcher(tx, articleText).match()
        article['fullText'] = ''
# Out:
#  Matching article 293 of 10420
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 5
#       3 print('\r', 'Matching article %s of %s' % (i, len(data)), end='')
#       4 if 'numMatches' not in article:
# ----> 5     articleText = Text(article['fullText'], article['id'])
#       6     article['numMatches'], article['Locations in A'], article['Locations in B'] = \
#       7     Matcher(tx, articleText).match()
#       8     article['fullText'] = ''
#
# File ~/Documents/GitHub/quotation-detection/text_matcher/matcher.py:26, in Text.__init__(self, raw_text, label, removeStopwords)
#      24 self.label = label
#      25 self.preprocess(self.text)
# ---> 26 self.tokens = self.getTokens(removeStopwords)
#      27 self.trigrams = self.ngrams(3)
#
# File ~/Documents/GitHub/quotation-detection/text_matcher/matcher.py:42, in Text.getTokens(self, removeStopwords)
#      40 tokens = [token.lower() for token in tokens]  # make them lowercase
#      41 stemmer = LancasterStemmer()
# ---> 42 tokens = [stemmer.stem(token) for token in tokens]
#      43 if not removeStopwords:
#      44     self.spans = spans
#
# File ~/Documents/GitHub/quotation-detection/text_matcher/matcher.py:42, in <listcomp>(.0)
#      40 tokens = [token.lower() for token in tokens]  # make them lowercase
#      41 stemmer = LancasterStemmer()
# ---> 42 tokens = [stemmer.stem(token) for token in tokens]
#      43 if not removeStopwords:
#      44     self.spans = spans
#
# File ~/anaconda3/lib/python3.10/site-packages/nltk/stem/lancaster.py:217, in LancasterStemmer.stem(self, word)
#     214 if not self.rule_dictionary:
#     215     self.parseRules()
# --> 217 return self.__doStemming(word, intact_word)
#
# File ~/anaconda3/lib/python3.10/site-packages/nltk/stem/lancaster.py:255, in LancasterStemmer.__doStemming(self, word, intact_word)
#     245 (
#     246     ending_string,
#     247     intact_flag,
#    (...)
#     250     cont_flag,
#     251 ) = rule_match.groups()
#     253 # Convert the number of chars to remove when stemming
#     254 # from a string to an integer
# --> 255 remove_total = int(remove_total)
#     257 # Proceed if word's ending matches rule's word ending
#     258 if word.endswith(ending_string[::-1]):
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(data)
df = df.drop(['fullText'], axis=1)

df.to_json(path_or_buf=f"{resultsDir}/{projectName}_results.jsonl", orient='records', lines=True)

# %%
df.loc[pd.notnull(df['Locations in A'])]
# Out:
#                    creator datePublished        docSubType  docType  \
# 0    [Christophe Ippolito]    2008-01-01  research-article  article
# 1                      NaN    1990-11-01              misc  article
# 2            [Ian Finseth]    1999-04-01  research-article  article
# 3       [Vern L. Bullough]    1989-07-01  research-article  article
# 4         [George Huppert]    1974-10-01  research-article  article
# ..                     ...           ...               ...      ...
# 288        [Philip Lorenz]    2006-10-01  research-article  article
# 289     [Brian Keith Axel]    2006-08-01  research-article  article
# 290      [Maria E. Cotera]    2013-03-01       book-review  article
# 291        [Ivy G. Wilson]    2006-03-01  research-article  article
# 292        [Mark Schuller]    2007-01-01  research-article  article
#
#                                              id  \
# 0          http://www.jstor.org/stable/25834090
# 1           http://www.jstor.org/stable/2073165
# 2          http://www.jstor.org/stable/27746772
# 3          http://www.jstor.org/stable/44451381
# 4           http://www.jstor.org/stable/2504776
# ..                                          ...
# 288        http://www.jstor.org/stable/40060028
# 289         http://www.jstor.org/stable/3805129
# 290  http://www.jstor.org/stable/10.1086/668556
# 291        http://www.jstor.org/stable/25486325
# 292        http://www.jstor.org/stable/25613094
#
#                                             identifier  \
# 0    [{'name': 'issn', 'value': '00844152'}, {'name...
# 1    [{'name': 'issn', 'value': '00943061'}, {'name...
# 2    [{'name': 'issn', 'value': '00029823'}, {'name...
# 3    [{'name': 'issn', 'value': '00075140'}, {'name...
# 4    [{'name': 'issn', 'value': '00182656'}, {'name...
# ..                                                 ...
# 288  [{'name': 'issn', 'value': '08883769'}, {'name...
# 289  [{'name': 'issn', 'value': '08867356'}, {'name...
# 290  [{'name': 'issn', 'value': '00979740'}, {'name...
# 291  [{'name': 'issn', 'value': '00308129'}, {'name...
# 292  [{'name': 'issn', 'value': '00086533'}, {'name...
#
#                                        isPartOf language  \
# 0    The Year's Work in Modern Language Studies    [eng]
# 1                        Contemporary Sociology    [eng]
# 2          American Literary Realism, 1870-1910    [eng]
# 3           Bulletin of the History of Medicine    [eng]
# 4                            History and Theory    [eng]
# ..                                          ...      ...
# 288                       Religion & Literature    [eng]
# 289                       Cultural Anthropology    [eng]
# 290                                       Signs    [eng]
# 291                                        PMLA    [eng]
# 292                           Caribbean Studies    [eng]
#
#                    outputFormat  pageCount  ... wordCount numMatches  \
# 0    [unigram, bigram, trigram]       19.0  ...      7727        0.0
# 1    [unigram, bigram, trigram]        6.0  ...      2776        0.0
# 2    [unigram, bigram, trigram]       20.0  ...     10192        1.0
# 3    [unigram, bigram, trigram]       21.0  ...     10778        0.0
# 4    [unigram, bigram, trigram]       17.0  ...      8105        0.0
# ..                          ...        ...  ...       ...        ...
# 288  [unigram, bigram, trigram]       19.0  ...      8499        0.0
# 289  [unigram, bigram, trigram]       31.0  ...     14215        1.0
# 290  [unigram, bigram, trigram]       10.0  ...      3689        0.0
# 291  [unigram, bigram, trigram]       16.0  ...     10021        0.0
# 292  [unigram, bigram, trigram]       39.0  ...     15114        0.0
#
#          Locations in A    Locations in B  issueNumber  \
# 0                    []                []          NaN
# 1                    []                []            6
# 2    [(113193, 113396)]  [(52257, 52460)]            3
# 3                    []                []            2
# 4                    []                []            3
# ..                  ...               ...          ...
# 288                  []                []            3
# 289    [(31357, 31508)]       [(95, 247)]            3
# 290                  []                []            3
# 291                  []                []            2
# 292                  []                []            1
#
#                                               abstract subTitle keyphrase  \
# 0                                                  NaN      NaN       NaN
# 1                                                  NaN      NaN       NaN
# 2                                                  NaN      NaN       NaN
# 3                                                  NaN      NaN       NaN
# 4                                                  NaN      NaN       NaN
# ..                                                 ...      ...       ...
# 288                                                NaN      NaN       NaN
# 289  This article is a set of reflections on how a ...      NaN       NaN
# 290                                                NaN      NaN       NaN
# 291  Beginning with a reconsideration of the symbol...      NaN       NaN
# 292  In this article, I explore the limits of domin...      NaN       NaN
#
#     collection hasPartTitle
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# ..         ...          ...
# 288        NaN          NaN
# 289        NaN          NaN
# 290        NaN          NaN
# 291        NaN          NaN
# 292        NaN          NaN
#
# [293 rows x 31 columns]
