# %% [markdown]
# <font size=5>Run Text_Matcher Algorithm</font>

# %%
#Troubleshooting: !jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10 if you 
# get a message about the data rate limit
from matcher import Text, Matcher
import json
import pandas as pd
from IPython.display import clear_output

# %%
# ACTION: specify top-level data directory and project info here
# Make sure they match the info you specified in preprocessing

dataDir = "/Users/milan/Library/CloudStorage/GoogleDrive-mtt2126@columbia.edu/My Drive/iAnnotate/MIT/Quotable Content/Data"
authorSurname = "Foucault"
publicationYear = "1969"
textTitle = "Archaeology"

# %%
# Load variables
projectName = f"{authorSurname}_{publicationYear}_{textTitle}"
sourceDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Source"
corpusDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Corpus"
resultsDir = f"{dataDir}/{authorSurname}/{publicationYear}_{textTitle}/Results"

# %%
corpusFile = f"{corpusDir}/{projectName}_fulltext.jsonl"
with open(corpusFile) as f:
    rawProcessedData = f.readlines()
data = [json.loads(line) for line in rawProcessedData]

# Load the text you want to find quotations from. Replace text with the text file you want to use.

sourceText = f"{sourceDir}/{projectName}_plaintext.txt"
with open(sourceText) as f: 
    rawText = f.read()

tx = Text(rawText, projectName)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 4
#       2 with open(corpusFile) as f:
#       3     rawProcessedData = f.readlines()
# ----> 4 data = [json.loads(line) for line in rawProcessedData]
#       6 # Load the text you want to find quotations from. Replace text with the text file you want to use.
#       8 sourceText = f"{sourceDir}/{projectName}_plaintext.txt"
#
# Cell In[12], line 4, in <listcomp>(.0)
#       2 with open(corpusFile) as f:
#       3     rawProcessedData = f.readlines()
# ----> 4 data = [json.loads(line) for line in rawProcessedData]
#       6 # Load the text you want to find quotations from. Replace text with the text file you want to use.
#       8 sourceText = f"{sourceDir}/{projectName}_plaintext.txt"
#
# File ~/anaconda3/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/anaconda3/lib/python3.10/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %%
for i, article in enumerate(data): 
    clear_output()
    print('\r', 'Matching article %s of %s' % (i, len(data)), end='')
    if 'numMatches' not in article: 
        articleText = Text(article['fullText'], article['id'])
        article['numMatches'], article['Locations in A'], article['Locations in B'] = \
        Matcher(tx, articleText).match()
        article['fullText'] = ''
# Out:
#  Matching article 10419 of 10420

# %%
df = pd.DataFrame(data)
df = df.drop(['fullText'], axis=1)

df.to_json(path_or_buf=f"{resultsDir}/{projectName}_results.jsonl", orient='records', lines=True)

# %% [markdown]
# # Quality control

# %%
# Optional: reload results file (if resuming later)

resultsData = f"{resultsDir}/{projectName}_results.jsonl"
df = pd.read_json(resultsData, lines=True)

# %%
# Check that matcher ran on all lines in the dataset - result should be 0

df.loc[pd.isnull(df['Locations in A'])]
# Out:
# Empty DataFrame
# Columns: [creator, datePublished, docSubType, docType, id, identifier, isPartOf, language, outputFormat, pageCount, pageEnd, pageStart, pagination, provider, publicationYear, publisher, sourceCategory, tdmCategory, title, url, volumeNumber, wordCount, numMatches, Locations in A, Locations in B, issueNumber, abstract, subTitle, keyphrase, collection, hasPartTitle]
# Index: []
#
# [0 rows x 31 columns]

# %%
# Check how many items include at least 1 match

df.loc[df["numMatches"] >=1]
# Out:
#                         creator datePublished        docSubType  docType  \
# 2                 [Ian Finseth]    1999-04-01  research-article  article
# 15            [Gunther Teubner]    1989-01-01  research-article  article
# 38     [Karen Elizabeth Bishop]    2011-10-01       book-review  article
# 56             [Heike Schaefer]    2015-01-01  research-article  article
# 63             [Henk-Jan Kooij]    2015-11-01  research-article  article
# ...                         ...           ...               ...      ...
# 10332            [Colin Pedley]    1990-04-01  research-article  article
# 10336              [Tim Murphy]    2003-01-01  research-article  article
# 10378  [Samuel Hideo Yamashita]    1992-12-01       book-review  article
# 10406                      None    1976-11-01              misc  article
# 10410         [OMNIA EL SHAKRY]    2015-06-01  research-article  article
#
#                                          id  \
# 2      http://www.jstor.org/stable/27746772
# 15      http://www.jstor.org/stable/3053760
# 38     http://www.jstor.org/stable/41238302
# 56     http://www.jstor.org/stable/44071899
# 63     http://www.jstor.org/stable/26098720
# ...                                     ...
# 10332  http://www.jstor.org/stable/24042557
# 10336  http://www.jstor.org/stable/23550011
# 10378   http://www.jstor.org/stable/2719183
# 10406   http://www.jstor.org/stable/3129679
# 10410  http://www.jstor.org/stable/26577264
#
#                                               identifier  \
# 2      [{'name': 'issn', 'value': '00029823'}, {'name...
# 15     [{'name': 'issn', 'value': '00239216'}, {'name...
# 38     [{'name': 'issn', 'value': '02613050'}, {'name...
# 56     [{'name': 'issn', 'value': '03402827'}, {'name...
# 63     [{'name': 'issn', 'value': '14730952'}, {'name...
# ...                                                  ...
# 10332  [{'name': 'issn', 'value': '00438006'}, {'name...
# 10336  [{'name': 'issn', 'value': '09433058'}, {'name...
# 10378  [{'name': 'issn', 'value': '00730548'}, {'name...
# 10406  [{'name': 'issn', 'value': '0065972X'}, {'name...
# 10410  [{'name': 'issn', 'value': '00028762'}, {'name...
#
#                                                 isPartOf language  \
# 2                   American Literary Realism, 1870-1910    [eng]
# 15                                  Law & Society Review    [eng]
# 38                   Bulletin of Latin American Research    [eng]
# 56                     Amerikastudien / American Studies    [eng]
# 63                                       Planning Theory    [eng]
# ...                                                  ...      ...
# 10332                              The Wordsworth Circle    [eng]
# 10336           Method & Theory in the Study of Religion    [eng]
# 10378                 Harvard Journal of Asiatic Studies    [eng]
# 10406  Proceedings and Addresses of the American Phil...    [eng]
# 10410                     The American Historical Review    [eng]
#
#                      outputFormat  pageCount  ... wordCount numMatches  \
# 2      [unigram, bigram, trigram]       20.0  ...     10192          1
# 15     [unigram, bigram, trigram]       31.0  ...     14124          1
# 38     [unigram, bigram, trigram]        3.0  ...       865          1
# 56     [unigram, bigram, trigram]       18.0  ...      9602          1
# 63     [unigram, bigram, trigram]       21.0  ...     10661          1
# ...                           ...        ...  ...       ...        ...
# 10332  [unigram, bigram, trigram]        7.0  ...      6019          1
# 10336  [unigram, bigram, trigram]       20.0  ...      8693          1
# 10378  [unigram, bigram, trigram]       14.0  ...      4781          1
# 10406  [unigram, bigram, trigram]       49.0  ...     12039          1
# 10410  [unigram, bigram, trigram]       15.0  ...      9788          1
#
#            Locations in A    Locations in B  issueNumber  \
# 2      [[113193, 113396]]  [[52257, 52460]]            3
# 15     [[121523, 121709]]  [[23103, 23288]]            5
# 38     [[333653, 333937]]      [[206, 489]]            4
# 56       [[52485, 52730]]  [[10716, 10960]]            1
# 63     [[106799, 106888]]  [[11698, 11788]]            4
# ...                   ...               ...          ...
# 10332    [[52485, 52730]]  [[30417, 30663]]            2
# 10336    [[52485, 52730]]  [[46238, 46484]]            1
# 10378    [[89391, 89609]]    [[8971, 9195]]            2
# 10406       [[887, 1029]]  [[52708, 52849]]            2
# 10410  [[329500, 329632]]  [[24000, 24129]]            3
#
#                                                 abstract  \
# 2                                                   None
# 15                                                  None
# 38                                                  None
# 56     While the study of networks has proliferated i...
# 63     AbstractA central question within planning the...
# ...                                                  ...
# 10332                                               None
# 10336  This work is a synopsis of an argument for a s...
# 10378                                               None
# 10406                                               None
# 10410                                               None
#
#                                                 subTitle keyphrase collection  \
# 2                                                   None      None       None
# 15                                                  None      None       None
# 38                                                  None      None       None
# 56                                                  None      None       None
# 63              The innovation campus in the Netherlands      None       None
# ...                                                  ...       ...        ...
# 10332                                               None      None       None
# 10336                                               None      None       None
# 10378                                               None      None       None
# 10406                                               None      None       None
# 10410  The Vexed Archives of Decolonization in the Mi...      None       None
#
#       hasPartTitle
# 2             None
# 15            None
# 38            None
# 56            None
# 63            None
# ...            ...
# 10332         None
# 10336         None
# 10378         None
# 10406         None
# 10410         None
#
# [644 rows x 31 columns]

# %%
# Check some random items without matches to check for false negatives - easiest to refer to PDF


df.loc[df["numMatches"] == 0]
# Out:
#                                  creator datePublished        docSubType  \
# 0                  [Christophe Ippolito]    2008-01-01  research-article
# 1                                   None    1990-11-01              misc
# 3                     [Vern L. Bullough]    1989-07-01  research-article
# 4                       [George Huppert]    1974-10-01  research-article
# 5                     [Douglas Harrison]    2006-04-01  research-article
# ...                                  ...           ...               ...
# 10415                      [MONIKA KAUP]    2013-12-01  research-article
# 10416                [Alexander Spencer]    2014-08-01  research-article
# 10417     [פלג דור-חיים, Peleg Dor-haim]    2015-01-01  research-article
# 10418  [Michelle Bigenho, Henry Stobart]    2018-10-01  research-article
# 10419                   [Jason E. Glenn]    2001-11-01  research-article
#
#        docType                                    id  \
# 0      article  http://www.jstor.org/stable/25834090
# 1      article   http://www.jstor.org/stable/2073165
# 3      article  http://www.jstor.org/stable/44451381
# 4      article   http://www.jstor.org/stable/2504776
# 5      article  http://www.jstor.org/stable/20464152
# ...        ...                                   ...
# 10415  article  http://www.jstor.org/stable/43297932
# 10416  article  http://www.jstor.org/stable/44218756
# 10417  article  http://www.jstor.org/stable/26240971
# 10418  article  http://www.jstor.org/stable/26646268
# 10419  article  http://www.jstor.org/stable/23019782
#
#                                               identifier  \
# 0      [{'name': 'issn', 'value': '00844152'}, {'name...
# 1      [{'name': 'issn', 'value': '00943061'}, {'name...
# 3      [{'name': 'issn', 'value': '00075140'}, {'name...
# 4      [{'name': 'issn', 'value': '00182656'}, {'name...
# 5      [{'name': 'issn', 'value': '07425562'}, {'name...
# ...                                                  ...
# 10415  [{'name': 'issn', 'value': '00107484'}, {'name...
# 10416  [{'name': 'issn', 'value': '15283577'}, {'name...
# 10417  [{'name': 'issn', 'value': '23102063'}, {'name...
# 10418  [{'name': 'issn', 'value': '00035491'}, {'name...
# 10419  [{'name': 'issn', 'value': '02588501'}, {'name...
#
#                                                 isPartOf language  \
# 0             The Year's Work in Modern Language Studies    [eng]
# 1                                 Contemporary Sociology    [eng]
# 3                    Bulletin of the History of Medicine    [eng]
# 4                                     History and Theory    [eng]
# 5      The Journal of the Midwest Modern Language Ass...    [eng]
# ...                                                  ...      ...
# 10415                            Contemporary Literature    [eng]
# 10416                 International Studies Perspectives    [eng]
# 10417  Mikbatz: The Israel Journal of Group Psychothe...    [heb]
# 10418                          Anthropological Quarterly    [eng]
# 10419                  Journal of West Indian Literature    [eng]
#
#                      outputFormat  pageCount  ... wordCount numMatches  \
# 0      [unigram, bigram, trigram]       19.0  ...      7727          0
# 1      [unigram, bigram, trigram]        6.0  ...      2776          0
# 3      [unigram, bigram, trigram]       21.0  ...     10778          0
# 4      [unigram, bigram, trigram]       17.0  ...      8105          0
# 5      [unigram, bigram, trigram]       13.0  ...      5818          0
# ...                           ...        ...  ...       ...        ...
# 10415  [unigram, bigram, trigram]       37.0  ...     13599          0
# 10416  [unigram, bigram, trigram]       16.0  ...      9289          0
# 10417  [unigram, bigram, trigram]       16.0  ...      5248          0
# 10418  [unigram, bigram, trigram]       35.0  ...     15207          0
# 10419  [unigram, bigram, trigram]       53.0  ...     18475          0
#
#       Locations in A Locations in B  issueNumber  \
# 0                 []             []         None
# 1                 []             []            6
# 3                 []             []            2
# 4                 []             []            3
# 5                 []             []            1
# ...              ...            ...          ...
# 10415             []             []            4
# 10416             []             []            3
# 10417             []             []            2
# 10418             []             []            4
# 10419             []             []          1/2
#
#                                                 abstract subTitle keyphrase  \
# 0                                                   None     None      None
# 1                                                   None     None      None
# 3                                                   None     None      None
# 4                                                   None     None      None
# 5                                                   None     None      None
# ...                                                  ...      ...       ...
# 10415                                               None     None      None
# 10416  The article examines the attempt by some acade...     None      None
# 10417  לאורך ההיסטוריה האנושית מילאה "הקבוצה האינטימי...     None      None
# 10418  A "fever" of heritage registration (patrimonia...     None      None
# 10419                                               None     None      None
#
#       collection hasPartTitle
# 0           None         None
# 1           None         None
# 3           None         None
# 4           None         None
# 5           None         None
# ...          ...          ...
# 10415       None         None
# 10416       None         None
# 10417       None         None
# 10418       None         None
# 10419       None         None
#
# [9776 rows x 31 columns]
